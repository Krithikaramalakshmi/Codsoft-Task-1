# %% [markdown]
# # importing pandas and the dataset

# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\Dell\Downloads\advertising.csv')

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.plot(x='TV', y='Sales')
# Out:
# <AxesSubplot:xlabel='TV'>

# %%
sample = dict (linestyle='dashed', color='blue', linewidth=2.0)
lplot = data.plot( y = 'Sales', figsize= (10,6),**sample ) 
lplot.set_title('plot between sales and tv')
lplot.grid()
lplot.set_xlabel('TV')
lplot.set_ylabel('Sales');

# %%
sample2 = dict (linestyle='dashed', color='black', linewidth=1.2)
lplot = data.plot( y = 'Sales', figsize= (10,6),**sample2 ) 
lplot.set_title('plot between sales and radio')
lplot.grid()
lplot.set_xlabel('Radio')
lplot.set_ylabel('Sales');

# %%
sample3 = dict (linestyle='dashed', color='red', linewidth=0.5)
lplot = data.plot( y = 'Sales', figsize= (10,6),**sample3 ) 
lplot.set_title('plot between sales and radio')
lplot.grid()
lplot.set_xlabel('Newspaper')
lplot.set_ylabel('Sales');

# %%
datamain=data.head()

# %%
number=["1","2","3","4","5"]
datamain.insert(0, "no2", number)

# %%
datamain
# Out:
#   no2     TV  Radio  Newspaper  Sales
# 0   1  230.1   37.8       69.2   22.1
# 1   2   44.5   39.3       45.1   10.4
# 2   3   17.2   45.9       69.3   12.0
# 3   4  151.5   41.3       58.5   16.5
# 4   5  180.8   10.8       58.4   17.9

# %% [markdown]
# # Plotting the given data of sales with tv,radio and newspaper

# %%
graph= dict (linestyle='dashed', color=['red', 'green','black'], linewidth=1.2)
line_plot = datamain.plot( y = ['TV', 'Radio','Newspaper'], figsize= (10,6),**graph ) 
line_plot.set_title('sales plot for tv radio and newspaper')
line_plot.grid()
line_plot.set_xlabel('no2')
line_plot.set_ylabel('Sales');

# %% [markdown]
# # usage of corr() method to find the corelation between the data given

# %%
relation = data.corr()

# %%
relation["Sales"]
# Out:
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Sales        1.000000
# Name: Sales, dtype: float64

# %% [markdown]
# # predicting the model by spliting it into train and test data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
x = np.array(data.drop("Sales", axis=1))

y = np.array(data["Sales"])
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.5, random_state=42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
print(model.score(xtest, ytest))
# Out:
# 0.907313434112335

# %%
y_pred = model.predict(xtest)
print(y_pred)
# Out:
# [17.16476357 20.53462007 23.79409343  9.37649013 21.5543733  12.70565614
#  21.07501697  8.65901616 17.1649327  16.68880961  8.81064333  8.50772806
#  18.49625978  7.99206797 12.6490433  14.97505847  8.21430901 17.8315899
#  11.04517747 20.39090382 21.03789611 13.04490145 10.8380167  22.60805663
#   9.29695504  7.90993183 20.86663772 13.73422214 10.77402998  7.81466049
#  15.93037797 10.60011594 20.96308621 10.75971333 21.62040645 21.06641423
#  12.04203253 22.96452088 12.50662839  6.44808712 11.90179615 15.2260707
#   9.96234937  9.42826337 17.17466348  7.1773329  10.43383015 15.20066012
#  11.18582512 11.67054682 13.89305235 14.59633742 10.70250628  9.41652667
#   8.97328245 12.50638395 10.42520099 25.10626171  7.84829742 15.75779955
#  21.19652389 16.98178637 12.85633234 10.04779017 20.90930583  7.47385489
#  23.38321106  7.05294977 12.48595909 10.00774974 11.06136251  9.04689085
#  16.91371393 17.95852957 15.89957626 18.17963341 15.44454795 19.09968582
# ...

# %%
print(xtest)
# Out:
# [[163.3  31.6  52.9]
#  [195.4  47.7  52.9]
#  [292.9  28.3  43.2]
#  [ 11.7  36.9  45.2]
#  [220.3  49.    3.2]
#  [ 75.1  35.   52.7]
#  [216.8  43.9  27.2]
#  [ 50.   11.6  18.4]
#  [222.4   3.4  13.1]
#  [175.1  22.5  31.5]
#  [ 31.5  24.6   2.2]
#  [ 56.2   5.7  29.7]
#  [234.5   3.4  84.8]
#  [  5.4  29.9   9.4]
#  [139.5   2.1  26.6]
#  [170.2   7.8  35.2]
#  [  7.3  28.1  41.4]
#  [197.6  23.3  14.2]
#  [ 75.3  20.3  32.5]
#  [237.4  27.5  11. ]
#  [229.5  32.3  74.2]
#  [ 67.8  36.6 114. ]
#  [ 38.   40.3  11.9]
#  [250.9  36.5  72.3]
#  [ 69.    9.3   0.9]
#  [ 53.5   2.   21.4]
#  [213.5  43.   33.8]
#  [139.3  14.5  10.2]
#  [ 87.2  11.8  25.9]
#  [  8.4  27.2   2.1]
#  [199.8   2.6  21.2]
#  [ 69.2  20.5  18.3]
#  [198.9  49.4  60. ]
#  [ 16.9  43.7  89.4]
#  [280.7  13.9  37. ]
#  [238.2  34.3   5.3]
#  [ 48.3  47.    8.5]
#  [273.7  28.9  59.7]
#  [117.2  14.7   5.4]
#  [ 27.5   1.6  20.7]
#  [116.    7.7  23.1]
#  [177.    9.3   6.4]
#  [ 43.1  26.7  35.1]
# ...

# %%
final = np.array([[230.1, 37.8, 69.2]])
print(model.predict(final))

#given the data of the tv,newspaper,and sales ,the above would predict the sales data.
# Out:
# [21.37254028]

# %%
##another example

final = np.array([[44.5,39.3,45.1]])
print(model.predict(final))
# Out:
# [11.30252447]

# %%
final = np.array([[17.2,45.9,69.3]])
print(model.predict(final))
# Out:
# [10.58560762]

# %%
final = np.array([[151.5,41.3,58.5]])
print(model.predict(final))
# Out:
# [17.39501824]

# %%
final = np.array([[180.8,10.8,58.4]])
print(model.predict(final))
# Out:
# [15.91287266]

# %%
datamain
# Out:
#   no2     TV  Radio  Newspaper  Sales
# 0   1  230.1   37.8       69.2   22.1
# 1   2   44.5   39.3       45.1   10.4
# 2   3   17.2   45.9       69.3   12.0
# 3   4  151.5   41.3       58.5   16.5
# 4   5  180.8   10.8       58.4   17.9

# %%
final=["21.37254028","11.30252447","10.58560762","17.39501824","15.91287266"]
datamain.insert(5, "final_predict",final)

# %%
datamain
# Out:
#   no2     TV  Radio  Newspaper  Sales final_predict
# 0   1  230.1   37.8       69.2   22.1   21.37254028
# 1   2   44.5   39.3       45.1   10.4   11.30252447
# 2   3   17.2   45.9       69.3   12.0   10.58560762
# 3   4  151.5   41.3       58.5   16.5   17.39501824
# 4   5  180.8   10.8       58.4   17.9   15.91287266

# %%
graph= dict (linestyle='dashed', color=['red', 'green','black'], linewidth=1.2)
line_plot = datamain.plot( y = ['TV', 'Radio','Newspaper'], figsize= (10,6),**graph ) 
line_plot.set_title('predicted sales plot for tv radio and newspaper ')
line_plot.grid()
line_plot.set_xlabel('no2')
line_plot.set_ylabel('final_predict');
